# %%
import graphviz
import tensorflow as tf

# %%
model = tf.keras.models.load_model('models/mtl_model')
tf.keras.utils.plot_model(model, to_file='models/mtl_model.png', show_shapes=True, show_layer_names=True)
